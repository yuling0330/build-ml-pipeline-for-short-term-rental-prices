# %%
import yaml
import wandb
import numpy as np
import pandas as pd

from ydata_profiling import ProfileReport

import seaborn as sns
import matplotlib.pyplot as plt



sns.set()

# %%
with open("../../config.yaml", "r") as file:
    config = yaml.safe_load(file)

# %%
config
# Out:
# {'main': {'components_repository': 'https://github.com/udacity/build-ml-pipeline-for-short-term-rental-prices#components',
#   'project_name': 'nyc_airbnb',
#   'experiment_name': 'development',
#   'steps': 'all'},
#  'etl': {'sample': 'sample1.csv', 'min_price': 10, 'max_price': 350},
#  'data_check': {'kl_threshold': 0.2},
#  'modeling': {'test_size': 0.2,
#   'val_size': 0.2,
#   'random_seed': 42,
#   'stratify_by': 'neighbourhood_group',
#   'max_tfidf_features': 5,
#   'random_forest': {'n_estimators': 100,
#    'max_depth': 15,
#    'min_samples_split': 4,
#    'min_samples_leaf': 3,
#    'n_jobs': -1,
#    'criterion': 'mae',
#    'max_features': 0.5,
#    'oob_score': True}}}

# %%
# run = wandb.init(project=config['main']['project_name'], 
#                  group=config['main']['experiment_name'], 
#                  job_type="EDA", save_code=True)

# %%
# !pwd
# Out:
# /home/jovyan/work/MLOps/build-ml-pipeline-for-short-term-rental-prices/src/eda
