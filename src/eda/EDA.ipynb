# %%
import yaml
import wandb
import numpy as np
import pandas as pd

# from ydata_profiling import ProfileReport

# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
data_path = "/Users/yg9793/Desktop/study/MLOps/Machine Learning DevOps Engineer/Project/build-ml-pipeline-for-short-term-rental-prices/components/get_data/data/sample1.csv"
df = pd.read_csv(data_path)

# %%
df.price.hist(bins=100)
# Out:
# <Axes: >

# %%
df.price.describe()
# Out:
# count    20000.000000
# mean       153.269050
# std        243.325609
# min          0.000000
# 25%         69.000000
# 50%        105.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
print(df.price.min(), df.price.max())
# Out:
# 0 10000

# %%
condition = (df.price > 50) & (df.price < 200)
df.price[condition].hist(bins=100)
# Out:
# <Axes: >
